# %%
from tsai.all import *
from core import training, inference

# %%
edp = training.example_data_parameter(3)
edp.num_weeks = 5
df = edp.create_sample_dataframe()
df.head()
# Out:
# ['unique_id', 'var1', 'var2', 'var3', 'target']
#    time  unique_id      var1      var2      var3    target
# 0     0        1.0  0.074782  1.722170  1.786203  3.096953
# 1     1        1.0  0.149460  1.758990  1.751312  2.808450
# 2     2        1.0  0.223929  1.793349  1.713973  2.317278
# 3     3        1.0  0.298085  1.825201  1.674236  3.723285
# 4     4        1.0  0.371823  1.854499  1.632157  2.226323

# %%
swp = training.sliding_window_parameter()
tb = swp.create_training_batches(df)

# %%
tb.plot_batches()
# Out:
# Too many batches. Display only the first and last 5.

# %%
training.frame_data.plot_frame(df)

# %%
#tb.train_on_batches()
