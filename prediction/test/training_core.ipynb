# %%
from tsai.all import *
from core import training, inference

# %% [markdown]
# ## Creating sample data

# %%
edp = training.example_data_parameter(num_days=25, num_features=5)
df = edp.create_sample_dataframe()
df.head()
# Out:
# ['unique_id', 'var1', 'var2', 'var3', 'var4', 'var5', 'target']
#    time  unique_id      var1      var2      var3      var4      var5    target
# 0     0        1.0  0.517638  1.905278  1.541214 -0.239835 -1.800381  4.724296
# 1     1        1.0  1.000000  1.997773  1.158803 -0.745565 -1.964464  5.011010
# 2     2        1.0  1.414214  1.954123  0.697420 -1.200487 -1.994672  3.165269
# 3     3        1.0  1.732051  1.777302  0.188510 -1.573597 -1.888946  2.424266
# 4     4        1.0  1.931852  1.479361 -0.333247 -1.839470 -1.654492  2.938496

# %%
training.dataframe.plot(df)

# %% [markdown]
# ## Preprocessing and training in one line

# %%
learn = training.dataframe.train(df)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
# ...
