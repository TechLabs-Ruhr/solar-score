# %%
from tsai.all import *
from core import training, inference

# %% [markdown]
# ## Creating sample data

# %%
edp = training.example_data_parameter(num_days=25, num_features=5)
df = edp.create_sample_dataframe()
df.head()
# Out:
# ['unique_id', 'var1', 'var2', 'var3', 'var4', 'var5', 'target']
#    time  unique_id      var1      var2      var3      var4      var5    target
# 0     0        1.0  0.517638  1.905278  1.541214 -0.239835 -1.800381  3.924296
# 1     1        1.0  1.000000  1.997773  1.158803 -0.745565 -1.964464  3.511010
# 2     2        1.0  1.414214  1.954123  0.697420 -1.200487 -1.994672  4.765269
# 3     3        1.0  1.732051  1.777302  0.188510 -1.573597 -1.888946  2.324266
# 4     4        1.0  1.931852  1.479361 -0.333247 -1.839470 -1.654492  3.138496

# %%
training.dataframe.plot(df)

# %% [markdown]
# ## Preprocessing and training in one line

# %%
learn = training.dataframe.train(df)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='67' class='' max='101' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.34% [67/101 01:59<01:00]
#     </div>
#
#
#
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\InkaStinn\TechLabs\solar-score\prediction\test\training_core.ipynb Cell 6' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/InkaStinn/TechLabs/solar-score/prediction/test/training_core.ipynb#ch0000005?line=0'>1</a> learn = training.dataframe.train(df)
#
# File c:\Users\InkaStinn\TechLabs\solar-score\prediction\test\..\core\training.py:15, in dataframe.train(df)
#      <a href='file:///c%3A/Users/InkaStinn/TechLabs/solar-score/prediction/test/../core/training.py?line=12'>13</a> """Performs preprocessing and training on given DataFrame. Returns the Learner."""
#      <a href='file:///c%3A/Users/InkaStinn/TechLabs/solar-score/prediction/test/../core/training.py?line=13'>14</a> td = dataframe.get_train_data(df)
# ---> <a href='file:///c%3A/Users/InkaStinn/TechLabs/solar-score/prediction/test/../core/training.py?line=14'>15</a> return td.train_on_batches()
#
# File c:\Users\InkaStinn\TechLabs\solar-score\prediction\test\..\core\training.py:66, in train_data.train_on_batches(self, autosave, iterations)
#      <a href='file:///c%3A/Users/InkaStinn/TechLabs/solar-score/prediction/test/../core/training.py?line=63'>64</a> self.learn = ts_learner(dls, InceptionTimePlus, cbs=cbs, loss_func=mae, metrics=[mae, mse])
#      <a href='file:///c%3A/Users/InkaStinn/TechLabs/solar-score/prediction/test/../core/training.py?line=64'>65</a> if self.lrs is None:
# ---> <a href='file:///c%3A/Users/InkaStinn/TechLabs/solar-score/prediction/test/../core/training.py?line=65'>66</a>     self.lrs = self.learn.lr_find(suggest_funcs=(minimum, steep, valley, slide))
#      <a href='file:///c%3A/Users/InkaStinn/TechLabs/solar-score/prediction/test/../core/training.py?line=66'>67</a> self.learn.fit_one_cycle(iterations, lr_max=self.lrs.valley)
#      <a href='file:///c%3A/Users/InkaStinn/TechLabs/solar-score/prediction/test/../core/training.py?line=67'>68</a> self.trained = True
#
# File ~\anaconda3\envs\score\lib\site-packages\fastai\callback\schedule.py:285, in lr_find(self, start_lr, end_lr, num_it, stop_div, show_plot, suggest_funcs)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/callback/schedule.py?line=282'>283</a> n_epoch = num_it//len(self.dls.train) + 1
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/callback/schedule.py?line=283'>284</a> cb=LRFinder(start_lr=start_lr, end_lr=end_lr, num_it=num_it, stop_div=stop_div)
# --> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/callback/schedule.py?line=284'>285</a> with self.no_logging(): self.fit(n_epoch, cbs=cb)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/callback/schedule.py?line=285'>286</a> if suggest_funcs is not None:
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/callback/schedule.py?line=286'>287</a>     lrs, losses = tensor(self.recorder.lrs[num_it//10:-5]), tensor(self.recorder.losses[num_it//10:-5])
#
# File ~\anaconda3\envs\score\lib\site-packages\fastai\learner.py:221, in Learner.fit(self, n_epoch, lr, wd, cbs, reset_opt)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=218'>219</a> self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=219'>220</a> self.n_epoch = n_epoch
# --> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=220'>221</a> self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#
# File ~\anaconda3\envs\score\lib\site-packages\fastai\learner.py:163, in Learner._with_events(self, f, event_type, ex, final)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=161'>162</a> def _with_events(self, f, event_type, ex, final=noop):
# --> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=162'>163</a>     try: self(f'before_{event_type}');  f()
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=163'>164</a>     except ex: self(f'after_cancel_{event_type}')
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=164'>165</a>     self(f'after_{event_type}');  final()
#
# File ~\anaconda3\envs\score\lib\site-packages\fastai\learner.py:212, in Learner._do_fit(self)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=209'>210</a> for epoch in range(self.n_epoch):
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=210'>211</a>     self.epoch=epoch
# --> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=211'>212</a>     self._with_events(self._do_epoch, 'epoch', CancelEpochException)
#
# File ~\anaconda3\envs\score\lib\site-packages\fastai\learner.py:163, in Learner._with_events(self, f, event_type, ex, final)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=161'>162</a> def _with_events(self, f, event_type, ex, final=noop):
# --> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=162'>163</a>     try: self(f'before_{event_type}');  f()
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=163'>164</a>     except ex: self(f'after_cancel_{event_type}')
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=164'>165</a>     self(f'after_{event_type}');  final()
#
# File ~\anaconda3\envs\score\lib\site-packages\fastai\learner.py:206, in Learner._do_epoch(self)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=204'>205</a> def _do_epoch(self):
# --> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=205'>206</a>     self._do_epoch_train()
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=206'>207</a>     self._do_epoch_validate()
#
# File ~\anaconda3\envs\score\lib\site-packages\fastai\learner.py:198, in Learner._do_epoch_train(self)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=195'>196</a> def _do_epoch_train(self):
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=196'>197</a>     self.dl = self.dls.train
# --> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=197'>198</a>     self._with_events(self.all_batches, 'train', CancelTrainException)
#
# File ~\anaconda3\envs\score\lib\site-packages\fastai\learner.py:163, in Learner._with_events(self, f, event_type, ex, final)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=161'>162</a> def _with_events(self, f, event_type, ex, final=noop):
# --> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=162'>163</a>     try: self(f'before_{event_type}');  f()
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=163'>164</a>     except ex: self(f'after_cancel_{event_type}')
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=164'>165</a>     self(f'after_{event_type}');  final()
#
# File ~\anaconda3\envs\score\lib\site-packages\fastai\learner.py:169, in Learner.all_batches(self)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=166'>167</a> def all_batches(self):
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=167'>168</a>     self.n_iter = len(self.dl)
# --> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=168'>169</a>     for o in enumerate(self.dl): self.one_batch(*o)
#
# File ~\anaconda3\envs\score\lib\site-packages\tsai\learner.py:37, in one_batch(self, i, b)
#      <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/tsai/learner.py?line=34'>35</a> b_on_device = to_device(b, device=self.dls.device) if self.dls.device is not None else b
#      <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/tsai/learner.py?line=35'>36</a> self._split(b_on_device)
# ---> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/tsai/learner.py?line=36'>37</a> self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#
# File ~\anaconda3\envs\score\lib\site-packages\fastai\learner.py:163, in Learner._with_events(self, f, event_type, ex, final)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=161'>162</a> def _with_events(self, f, event_type, ex, final=noop):
# --> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=162'>163</a>     try: self(f'before_{event_type}');  f()
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=163'>164</a>     except ex: self(f'after_cancel_{event_type}')
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=164'>165</a>     self(f'after_{event_type}');  final()
#
# File ~\anaconda3\envs\score\lib\site-packages\fastai\learner.py:180, in Learner._do_one_batch(self)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=177'>178</a> if not self.training or not len(self.yb): return
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=178'>179</a> self('before_backward')
# --> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=179'>180</a> self.loss_grad.backward()
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=180'>181</a> self._with_events(self.opt.step, 'step', CancelStepException)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/learner.py?line=181'>182</a> self.opt.zero_grad()
#
# File ~\anaconda3\envs\score\lib\site-packages\torch\_tensor.py:299, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=251'>252</a> r"""Computes the gradient of current tensor w.r.t. graph leaves.
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=252'>253</a>
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=253'>254</a> The graph is differentiated using the chain rule. If the tensor is
#    (...)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=295'>296</a>         used to compute the attr::tensors.
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=296'>297</a> """
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=297'>298</a> if has_torch_function_unary(self):
# --> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=298'>299</a>     return handle_torch_function(
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=299'>300</a>         Tensor.backward,
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=300'>301</a>         (self,),
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=301'>302</a>         self,
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=302'>303</a>         gradient=gradient,
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=303'>304</a>         retain_graph=retain_graph,
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=304'>305</a>         create_graph=create_graph,
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=305'>306</a>         inputs=inputs)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=306'>307</a> torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~\anaconda3\envs\score\lib\site-packages\torch\overrides.py:1355, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/overrides.py?line=1348'>1349</a>     warnings.warn("Defining your `__torch_function__ as a plain method is deprecated and "
#    <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/overrides.py?line=1349'>1350</a>                   "will be an error in PyTorch 1.11, please define it as a classmethod.",
#    <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/overrides.py?line=1350'>1351</a>                   DeprecationWarning)
#    <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/overrides.py?line=1352'>1353</a> # Use `public_api` instead of `implementation` so __torch_function__
#    <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/overrides.py?line=1353'>1354</a> # implementations can do equality/identity comparisons.
# -> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/overrides.py?line=1354'>1355</a> result = torch_func_method(public_api, types, args, kwargs)
#    <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/overrides.py?line=1356'>1357</a> if result is not NotImplemented:
#    <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/overrides.py?line=1357'>1358</a>     return result
#
# File ~\anaconda3\envs\score\lib\site-packages\fastai\torch_core.py:340, in TensorBase.__torch_function__(self, func, types, args, kwargs)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/torch_core.py?line=337'>338</a> convert=False
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/torch_core.py?line=338'>339</a> if _torch_handled(args, self._opt, func): convert,types = type(self),(torch.Tensor,)
# --> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/torch_core.py?line=339'>340</a> res = super().__torch_function__(func, types, args=args, kwargs=kwargs)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/torch_core.py?line=340'>341</a> if convert: res = convert(res)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/fastai/torch_core.py?line=341'>342</a> if isinstance(res, TensorBase): res.set_meta(self, as_copy=True)
#
# File ~\anaconda3\envs\score\lib\site-packages\torch\_tensor.py:1051, in Tensor.__torch_function__(cls, func, types, args, kwargs)
#    <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=1047'>1048</a>     return NotImplemented
#    <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=1049'>1050</a> with _C.DisableTorchFunction():
# -> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=1050'>1051</a>     ret = func(*args, **kwargs)
#    <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=1051'>1052</a>     if func in get_default_nowrap_functions():
#    <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=1052'>1053</a>         return ret
#
# File ~\anaconda3\envs\score\lib\site-packages\torch\_tensor.py:307, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=297'>298</a> if has_torch_function_unary(self):
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=298'>299</a>     return handle_torch_function(
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=299'>300</a>         Tensor.backward,
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=300'>301</a>         (self,),
#    (...)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=304'>305</a>         create_graph=create_graph,
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=305'>306</a>         inputs=inputs)
# --> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/_tensor.py?line=306'>307</a> torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~\anaconda3\envs\score\lib\site-packages\torch\autograd\__init__.py:154, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/autograd/__init__.py?line=150'>151</a> if retain_graph is None:
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/autograd/__init__.py?line=151'>152</a>     retain_graph = create_graph
# --> <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/autograd/__init__.py?line=153'>154</a> Variable._execution_engine.run_backward(
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/autograd/__init__.py?line=154'>155</a>     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     <a href='file:///c%3A/Users/InkaStinn/anaconda3/envs/score/lib/site-packages/torch/autograd/__init__.py?line=155'>156</a>     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
