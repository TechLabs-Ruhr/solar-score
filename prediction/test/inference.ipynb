# %%
from tsai.all import *

# %% [markdown]
# Loading data produced by `shapes.ipynb`

# %%
learn = load_learner(Path('models/shapes.pkl'))
X2 = np.load(Path('data/X2.npy'))
y2 = np.load(Path('data/y2.npy'))
splits = np.load(Path('data/splits.npy'), allow_pickle=True)

# %% [markdown]
# Make predictions

# %%
probas, _, preds = learn.get_X_preds(X2[splits[1]])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# Show validations

# %%
i = 100
plt.plot(y2[splits[1],i])
plt.plot(preds[i,:])
plt.show()
