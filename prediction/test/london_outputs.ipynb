# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
path = Path('data/london')

# %%
customer_endpoints = pd.read_csv(Path(path/'EXPORT HourlyData - Customer Endpoints.csv'))
customer_endpoints.head()
customer_endpoints.Substation.unique()
# Out:
# array(['Forest Road', 'Suffolk Road', 'Bancroft Close', 'Alverston Close',
#        'Maple Drive East', 'YMCA'], dtype=object)

# %%
feeders = pd.read_csv(Path(path/'EXPORT HourlyData - Feeders.csv'))
feeders.head()
# Out:
# C:\Users\Marian\AppData\Local\Temp\ipykernel_7436\1176783351.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   feeders = pd.read_csv(Path(path/'EXPORT HourlyData - Feeders.csv'))
#            SerialNo       Substation   Type2               To  \
# 0  3067D03000000427  Warninglid Lane  Feeder  Warninglid Lane
# 1  3067D03000000427  Warninglid Lane  Feeder  Warninglid Lane
# 2  3067D03000000427  Warninglid Lane  Feeder  Warninglid Lane
# 3  3067D03000000427  Warninglid Lane  Feeder  Warninglid Lane
# 4  3067D03000000427  Warninglid Lane  Feeder  Warninglid Lane
#
#               datetime      t_date    t_time   d_y  d_m  d_d  ...  thdIC_min  \
# 0  2014-09-01 00:00:00  2014-09-01  00:00:00  2014    9    1  ...     12.479
# 1  2014-09-01 01:00:00  2014-09-01  01:00:00  2014    9    1  ...     11.554
# 2  2014-09-01 02:00:00  2014-09-01  02:00:00  2014    9    1  ...     11.938
# ...

# %%
network_endpoints = pd.read_csv(Path(path/'EXPORT HourlyData - Network Endpoints.csv'))
network_endpoints.head()
# Out:
# C:\Users\Marian\AppData\Local\Temp\ipykernel_7436\3086563607.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   network_endpoints = pd.read_csv(Path(path/'EXPORT HourlyData - Network Endpoints.csv'))
#             SerialNo      Substation     Type2       To             datetime  \
# 0  3067D03000000427X  Bircham Newton  Endpoint  Network  2013-11-09 12:00:00
# 1  3067D03000000427X  Bircham Newton  Endpoint  Network  2013-11-09 13:00:00
# 2  3067D03000000427X  Bircham Newton  Endpoint  Network  2013-11-09 14:00:00
# 3  3067D03000000427X  Bircham Newton  Endpoint  Network  2013-11-09 15:00:00
# 4  3067D03000000427X  Bircham Newton  Endpoint  Network  2013-11-09 16:00:00
#
#        t_date    t_time   d_y  d_m  d_d  ...  Substation_thdVB_MIN_Filtered  \
# 0  2013-11-09  12:00:00  2013   11    9  ...                          1.356
# 1  2013-11-09  13:00:00  2013   11    9  ...                          1.325
# ...

# %%
substation_voltages = pd.read_csv(Path(path/'EXPORT HourlyData - Substation Voltages.csv'))
substation_voltages.head()
# Out:
#         Substation             datetime      t_date    t_time   d_y  d_m  d_d  \
# 0  Alverston Close  2013-07-27 03:00:00  2013-07-27  03:00:00  2013    7   27
# 1  Alverston Close  2013-07-27 04:00:00  2013-07-27  04:00:00  2013    7   27
# 2  Alverston Close  2013-07-27 05:00:00  2013-07-27  05:00:00  2013    7   27
# 3  Alverston Close  2013-07-27 06:00:00  2013-07-27  06:00:00  2013    7   27
# 4  Alverston Close  2013-07-27 07:00:00  2013-07-27  07:00:00  2013    7   27
#
#    d_w  t_h  t_m  ...  Substation_VB_MIN_Filtered  Substation_VB_MAX_Filtered  \
# 0    6    3    0  ...                     242.408                     243.341
# 1    6    4    0  ...                     242.299                     242.941
# 2    6    5    0  ...                     243.172                     244.155
# 3    6    6    0  ...                     240.845                     243.078
# 4    6    7    0  ...                     241.121                     243.379
#
# ...

# %%
def plot_substation_voltages(substation='Alverston Close', slice=slice(100)):
    tmp = substation_voltage[substation_voltage['Substation'] == substation]
    tmp = tmp.iloc[slice]
    
    fig, axs = plt.subplots(1, 6, figsize=(25,5))
    tmp.plot(x='datetime', y=['Substation_VA_MIN_Filtered', 'Substation_VA_MAX_Filtered'], ax=axs[0])
    tmp.plot(x='datetime', y=['Substation_VB_MIN_Filtered', 'Substation_VB_MAX_Filtered'], ax=axs[1])
    tmp.plot(x='datetime', y=['Substation_VC_MIN_Filtered', 'Substation_VC_MAX_Filtered'], ax=axs[2])
    tmp.plot(x='datetime', y=['Substation_thdVA_MIN_Filtered', 'Substation_thdVA_MAX_Filtered'], ax=axs[3])
    tmp.plot(x='datetime', y=['Substation_thdVB_MIN_Filtered', 'Substation_thdVB_MAX_Filtered'], ax=axs[4])
    tmp.plot(x='datetime', y=['Substation_thdVC_MIN_Filtered', 'Substation_thdVC_MAX_Filtered'], ax=axs[5])

# %%
plot_substation_voltages()

# %%
print(list(customer_endpoints))
print(len(list(customer_endpoints)))
# Out:
# ['SerialNo', 'Substation', 'datetime', 't_date', 't_time', 'd_y', 'd_m', 'd_d', 'd_w', 't_h', 't_m', 'V_MIN', 'V_MIN_Filtered', 'V_MAX', 'V_MAX_Filtered', 'I_GEN_MIN', 'I_GEN_MIN_Filtered', 'I_GEN_MAX', 'I_GEN_MAX_Filtered', 'I_IMPORT_MIN', 'I_IMPORT_MIN_Filtered', 'I_IMPORT_MAX', 'I_IMPORT_MAX_Filtered', 'P_GEN_MIN', 'P_GEN_MAX', 'P_IMPORT_MIN', 'P_IMPORT_MAX', 'Q_GEN_MIN', 'Q_GEN_MAX', 'Q_IMPORT_MIN', 'Q_IMPORT_MAX', 'S_GEN_MIN', 'S_GEN_MAX', 'S_IMPORT_MIN', 'S_IMPORT_MAX', 'thdV_MIN', 'thdV_MIN_Filtered', 'thdV_MAX', 'thdV_MAX_Filtered', 'thdI_GEN_MIN', 'thdI_GEN_MAX', 'thdI_IMPORT_MIN', 'thdI_IMPORT_MAX', 'f_min', 'f_max', 'Substation_VA_MIN_Filtered', 'Substation_VA_MAX_Filtered', 'Substation_VB_MIN_Filtered', 'Substation_VB_MAX_Filtered', 'Substation_VC_MIN_Filtered', 'Substation_VC_MAX_Filtered', 'Substation_thdVA_MIN_Filtered', 'Substation_thdVA_MAX_Filtered', 'Substation_thdVB_MIN_Filtered', 'Substation_thdVB_MAX_Filtered', 'Substation_thdVC_MIN_Filtered', 'Substation_thdVC_
# ...

# %%
print(list(feeders))
print(len(list(feeders)))
# Out:
# ['SerialNo', 'Substation', 'Type2', 'To', 'datetime', 't_date', 't_time', 'd_y', 'd_m', 'd_d', 'd_w', 't_h', 't_m', 'VA_MIN', 'VA_MIN_Filtered', 'VA_MAX', 'VA_MAX_Filtered', 'VB_MIN', 'VB_MIN_Filtered', 'VB_MAX', 'VB_MAX_Filtered', 'VC_MIN', 'VC_MIN_Filtered', 'VC_MAX', 'VC_MAX_Filtered', 'IA_MIN', 'IA_MIN_Filtered', 'IA_MAX', 'IA_MAX_Filtered', 'IB_MIN', 'IB_MIN_Filtered', 'IB_MAX', 'IB_MAX_Filtered', 'IC_MIN', 'IC_MIN_Filtered', 'IC_MAX', 'IC_MAX_Filtered', 'IN_MIN', 'IN_MIN_Filtered', 'IN_MAX', 'IN_MAX_Filtered', 'PA_MIN', 'PA_MAX', 'PB_MIN', 'PB_MAX', 'PC_MIN', 'PC_MAX', 'QA_MIN', 'QA_MAX', 'QB_MIN', 'QB_MAX', 'QC_MIN', 'QC_MAX', 'SA_MIN', 'SA_MAX', 'SB_MIN', 'SB_MAX', 'SC_MIN', 'SC_MAX', 'thdVA_min', 'thdVA_MIN_Filtered', 'thdVA_max', 'thdVA_MAX_Filtered', 'thdVB_min', 'thdVB_MIN_Filtered', 'thdVB_max', 'thdVB_MAX_Filtered', 'thdVC_min', 'thdVC_MIN_Filtered', 'thdVC_max', 'thdVC_MAX_Filtered', 'thdIA_min', 'thdIA_max', 'thdIB_min', 'thdIB_max', 'thdIC_min', 'thdIC_max', 'thdIN_m
# ...

# %%
print(list(network_endpoints))
print(len(list(network_endpoints)))
# Out:
# ['SerialNo', 'Substation', 'Type2', 'To', 'datetime', 't_date', 't_time', 'd_y', 'd_m', 'd_d', 'd_w', 't_h', 't_m', 'VA_MIN', 'VA_MIN_Filtered', 'VA_MAX', 'VA_MAX_Filtered', 'VB_MIN', 'VB_MIN_Filtered', 'VB_MAX', 'VB_MAX_Filtered', 'VC_MIN', 'VC_MIN_Filtered', 'VC_MAX', 'VC_MAX_Filtered', 'IA_MIN', 'IA_MIN_Filtered', 'IA_MAX', 'IA_MAX_Filtered', 'IB_MIN', 'IB_MIN_Filtered', 'IB_MAX', 'IB_MAX_Filtered', 'IC_MIN', 'IC_MIN_Filtered', 'IC_MAX', 'IC_MAX_Filtered', 'IN_MIN', 'IN_MIN_Filtered', 'IN_MAX', 'IN_MAX_Filtered', 'PA_MIN', 'PA_MAX', 'PB_MIN', 'PB_MAX', 'PC_MIN', 'PC_MAX', 'QA_MIN', 'QA_MAX', 'QB_MIN', 'QB_MAX', 'QC_MIN', 'QC_MAX', 'SA_MIN', 'SA_MAX', 'SB_MIN', 'SB_MAX', 'SC_MIN', 'SC_MAX', 'thdVA_min', 'thdVA_MIN_Filtered', 'thdVA_max', 'thdVA_MAX_Filtered', 'thdVB_min', 'thdVB_MIN_Filtered', 'thdVB_max', 'thdVB_MAX_Filtered', 'thdVC_min', 'thdVC_MIN_Filtered', 'thdVC_max', 'thdVC_MAX_Filtered', 'thdIA_min', 'thdIA_max', 'thdIB_min', 'thdIB_max', 'thdIC_min', 'thdIC_max', 'thdIN_m
# ...

# %%
print(list(substation_voltages))
print(len(list(substation_voltages)))
# Out:
# ['Substation', 'datetime', 't_date', 't_time', 'd_y', 'd_m', 'd_d', 'd_w', 't_h', 't_m', 'Substation_VA_MIN_Filtered', 'Substation_VA_MAX_Filtered', 'Substation_VB_MIN_Filtered', 'Substation_VB_MAX_Filtered', 'Substation_VC_MIN_Filtered', 'Substation_VC_MAX_Filtered', 'Substation_thdVA_MIN_Filtered', 'Substation_thdVA_MAX_Filtered', 'Substation_thdVB_MIN_Filtered', 'Substation_thdVB_MAX_Filtered', 'Substation_thdVC_MIN_Filtered', 'Substation_thdVC_MAX_Filtered']
# 22
