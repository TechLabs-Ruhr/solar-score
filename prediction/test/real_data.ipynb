# %%
from tsai.all import *
from core import training, inferencing

# %%
df = pd.read_csv(Path(Path.cwd().parent.parent/'data/Trainingsdata/model input CSVs/input All.csv'), delimiter=';')
df.columns
# Out:
# Index(['Site', 'Time', 'TempOut [K]', 'DewPt [K]', 'WindSpeed [m/s]',
#        'SolarRad [kJ/m²]', 'P_gen [kW]', 'unique_id'],
#       dtype='object')

# %%
training.dataframe.plot_all(df)

# %%
for id in df['unique_id'].unique():
    training.dataframe.get_time_delta(df, id)
# Out:
# 11.0     29 days, 0:00:00
# 13.0     65 days, 19:00:00
# 17.0     28 days, 13:00:00
# 19.0     26 days, 8:00:00
# 22.0     27 days, 3:00:00
# 153.0     35 days, 1:00:00
# 154.0     27 days, 2:00:00
# 161.0     81 days, 21:00:00
# 162.0     73 days, 7:00:00

# %%
training.dataframe.plot_batches(df)
# Out:
# Too many batches. Display only the first and last 5.

# %%
training.dataframe.train(df)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.206854</td>
#       <td>0.123348</td>
#       <td>0.123348</td>
#       <td>0.028502</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.116007</td>
#       <td>0.084472</td>
#       <td>0.084472</td>
#       <td>0.017527</td>
#       <td>01:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.088672</td>
#       <td>0.079815</td>
#       <td>0.079815</td>
#       <td>0.016738</td>
#       <td>01:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.078552</td>
#       <td>0.077894</td>
#       <td>0.077894</td>
#       <td>0.015002</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.073024</td>
#       <td>0.074928</td>
#       <td>0.074928</td>
#       <td>0.013954</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.067162</td>
#       <td>0.070614</td>
#       <td>0.070614</td>
#       <td>0.012806</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.061721</td>
#       <td>0.063341</td>
#       <td>0.063341</td>
#       <td>0.011179</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.057854</td>
#       <td>0.073290</td>
#       <td>0.073290</td>
#       <td>0.013863</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.053160</td>
#       <td>0.067783</td>
#       <td>0.067783</td>
#       <td>0.011872</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.050715</td>
#       <td>0.060137</td>
#       <td>0.060137</td>
#       <td>0.008499</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.046672</td>
#       <td>0.062067</td>
#       <td>0.062067</td>
#       <td>0.009853</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.044671</td>
#       <td>0.056898</td>
#       <td>0.056898</td>
#       <td>0.008594</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.043033</td>
#       <td>0.050225</td>
#       <td>0.050225</td>
#       <td>0.006372</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.044282</td>
#       <td>0.051499</td>
#       <td>0.051499</td>
#       <td>0.006294</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.041719</td>
#       <td>0.064275</td>
#       <td>0.064275</td>
#       <td>0.011253</td>
#       <td>01:17</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.039417</td>
#       <td>0.052555</td>
#       <td>0.052555</td>
#       <td>0.006908</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.039398</td>
#       <td>0.049697</td>
#       <td>0.049697</td>
#       <td>0.005687</td>
#       <td>01:20</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0
td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.018692</td>
#       <td>0.042755</td>
#       <td>0.042755</td>
#       <td>0.004965</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.018339</td>
#       <td>0.035367</td>
#       <td>0.035367</td>
#       <td>0.003028</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.018128</td>
#       <td>0.053149</td>
#       <td>0.053149</td>
#       <td>0.008757</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.016949</td>
#       <td>0.036431</td>
#       <td>0.036431</td>
#       <td>0.003338</td>
#       <td>01:13</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.016013</td>
#       <td>0.044231</td>
#       <td>0.044231</td>
#       <td>0.005194</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.016194</td>
#       <td>0.038236</td>
#       <td>0.038236</td>
#       <td>0.003749</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.016531</td>
#       <td>0.038407</td>
#       <td>0.038407</td>
#       <td>0.003795</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.015027</td>
#       <td>0.033
# Better model found at epoch 0 with valid_loss value: 0.123347707092762.
# Better model found at epoch 1 with valid_loss value: 0.08447166532278061.
# Better model found at epoch 2 with valid_loss value: 0.07981481403112411.
# Better model found at epoch 3 with valid_loss value: 0.07789446413516998.
# Better model found at epoch 4 with valid_loss value: 0.07492789626121521.
# Better model found at epoch 5 with valid_loss value: 0.0706140398979187.
# Better model found at epoch 6 with valid_loss value: 0.06334096938371658.
# Better model found at epoch 9 with valid_loss value: 0.06013721227645874.
# Better model found at epoch 11 with valid_loss value: 0.05689806491136551.
# Better model found at epoch 12 with valid_loss value: 0.050224531441926956.
# Better model found at epoch 21 with valid_loss value: 0.04887823015451431.
# Better model found at epoch 22 with valid_loss value: 0.04241397604346275.
# Better model found at epoch 32 with valid_loss value: 0.03874726593494415.
# Better model found at epoch 37 with valid_loss value: 0.03745820373296738.
# Better model found at epoch 42 with valid_loss value: 0.03594469651579857.
# Better model found at epoch 50 with valid_loss value: 0.03365877643227577.
# Better model found at epoch 59 with valid_loss value: 0.03198797255754471.
# No improvement since epoch 59: early stopping

# %%
inferencing.dataframe.validate(df.iloc[-240:])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <module>
# ----> 1 inferencing.dataframe.validate(df.iloc[-240:])
#
# File c:\Users\Marian\Documents\Git\solar-score\prediction\test\..\core\inferencing.py:34, in dataframe.validate(df)
#      <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/inferencing.py?line=30'>31</a> preds[preds<0] = 0
#      <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/inferencing.py?line=32'>33</a> plt.figure(figsize=(20, 6))
# ---> <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/inferencing.py?line=33'>34</a> plt.plot(id.y[0]);
#      <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/inferencing.py?line=34'>35</a> plt.plot(preds)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
learn = load_learner(Path('models/core.pkl'))
