# %%
from tsai.all import *
from core import training, inference

# %%
df = pd.read_csv(Path(Path.cwd().parent.parent/'data/Trainingsdata/model input CSVs/input All.csv'), delimiter=';')
#df = training.dataframe.prepare(df)
training.dataframe.plot_all(df)

# %%
training.dataframe.get_time_delta(df)
# Out:
# 10172    2014-11-19 18:00:00
# Name: Time, dtype: object

# %%
training.dataframe.plot_batches(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [4], in <module>
# ----> 1 training.dataframe.plot_batches(df)
#
# File c:\Users\Marian\Documents\Git\solar-score\prediction\test\..\core\training.py:23, in dataframe.plot_batches(df)
#      <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/training.py?line=20'>21</a> """"""
#      <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/training.py?line=21'>22</a> swp = sliding_window_parameter(num_features=4)
# ---> <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/training.py?line=22'>23</a> td = swp.create_training_data(df)
#      <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/training.py?line=23'>24</a> td.plot_batches()
#
# File c:\Users\Marian\Documents\Git\solar-score\prediction\test\..\core\training.py:250, in sliding_window_parameter.create_training_data(self, df, target_column)
#     <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/training.py?line=224'>225</a> self.get_y = [target_column]
#     <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/training.py?line=226'>227</a> output = [df.groupby(['unique_id']).apply(lambda x: SlidingWindow(
#     <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/training.py?line=227'>228</a>     add_padding_feature=self.add_padding_feature,
#     <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/training.py?line=228'>229</a>     ascending=self.ascending,
#    (...)
#     <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/training.py?line=246'>247</a>     y_func=self.y_func,
#     <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/training.py?line=247'>248</a> )(x))][0].values
# --> <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/training.py?line=249'>250</a> X = np.concatenate([oi[0] for oi in output])
#     <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/training.py?line=250'>251</a> y = np.concatenate([oi[1] for oi in output])
#     <a href='file:///c%3A/Users/Marian/Documents/Git/solar-score/prediction/test/../core/training.py?line=251'>252</a> splits = get_splits(o=y, n_splits=1, valid_size=.2, shuffle=False)
#
# File <__array_function__ internals>:5, in concatenate(*args, **kwargs)
#
# ValueError: zero-dimensional arrays cannot be concatenated

# %%
training.dataframe.train(df)

# %%
inference.dataframe.validate(df)
