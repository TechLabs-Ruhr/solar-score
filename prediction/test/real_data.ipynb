# %%
from tsai.all import *
from core import training, inference

# %%
df = pd.read_csv(Path(Path.cwd().parent.parent/'data/Trainingsdata/model input CSVs/input All.csv'), delimiter=';')
#df = training.dataframe.prepare(df)
training.dataframe.plot_all(df)

# %%
for id in df['unique_id'].unique():
    training.dataframe.get_time_delta(df, id)
# Out:
# 11.0     29 days, 0:00:00
# 13.0     65 days, 19:00:00
# 17.0     28 days, 13:00:00
# 19.0     26 days, 8:00:00
# 22.0     27 days, 3:00:00
# 153.0     35 days, 1:00:00
# 154.0     27 days, 2:00:00
# 161.0     81 days, 21:00:00
# 162.0     73 days, 7:00:00

# %%
training.dataframe.plot_batches(df)
# Out:
# Too many batches. Display only the first and last 5.

# %%
training.dataframe.train(df)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.243509</td>
#       <td>0.130722</td>
#       <td>0.130722</td>
#       <td>0.031573</td>
#       <td>01:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.125475</td>
#       <td>0.088826</td>
#       <td>0.088826</td>
#       <td>0.018686</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.092132</td>
#       <td>0.083114</td>
#       <td>0.083114</td>
#       <td>0.017479</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.080187</td>
#       <td>0.078289</td>
#       <td>0.078289</td>
#       <td>0.015816</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.073284</td>
#       <td>0.076563</td>
#       <td>0.076563</td>
#       <td>0.015382</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.068057</td>
#       <td>0.084701</td>
#       <td>0.084701</td>
#       <td>0.018156</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.061034</td>
#       <td>0.065248</td>
#       <td>0.065248</td>
#       <td>0.010729</td>
#       <td>01:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.055691</td>
#       <td>0.060194</td>
#       <td>0.060194</td>
#       <td>0.009293</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.051656</td>
#       <td>0.068275</td>
#       <td>0.068275</td>
#       <td>0.010623</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.049948</td>
#       <td>0.069865</td>
#       <td>0.069865</td>
#       <td>0.013140</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.046699</td>
#       <td>0.051182</td>
#       <td>0.051182</td>
#       <td>0.006489</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.045782</td>
#       <td>0.060431</td>
#       <td>0.060431</td>
#       <td>0.008849</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.045635</td>
#       <td>0.051306</td>
#       <td>0.051306</td>
#       <td>0.006679</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.044111</td>
#       <td>0.061433</td>
#       <td>0.061433</td>
#       <td>0.008267</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.042837</td>
#       <td>0.071217</td>
#       <td>0.071217</td>
#       <td>0.013605</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.041860</td>
#       <td>0.082433</td>
#       <td>0.082433</td>
#       <td>0.019998</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.042256</td>
#       <td>0.059965</td>
#       <td>0.059965</td>
#       <td>0.009251</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.040566</td>
#       <td>0.060195</td>
#       <td>0.060195</td>
#       <td>0.009077</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.039552</td>
#       <td>0.074668</td>
#       <td>0.074668</td>
#       <td>0.015860</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.038584</td>
#       <td>0.077801</td>
#       <td>0.077801</td>
#       <td>0.012978</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.038437</td>
#       <td>0.101991</td>
#       <td>0.101991</td>
#       <td>0.029027</td>
#       <td>01:07</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.13072174787521362.
# Better model found at epoch 1 with valid_loss value: 0.08882608264684677.
# Better model found at epoch 2 with valid_loss value: 0.083114393055439.
# Better model found at epoch 3 with valid_loss value: 0.07828915119171143.
# Better model found at epoch 4 with valid_loss value: 0.07656251639127731.
# Better model found at epoch 6 with valid_loss value: 0.06524796783924103.
# Better model found at epoch 7 with valid_loss value: 0.06019449234008789.
# Better model found at epoch 10 with valid_loss value: 0.051181502640247345.
# No improvement since epoch 10: early stopping

# %%
inference.dataframe.validate(df.iloc[-240:])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
