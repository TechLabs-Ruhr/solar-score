# %%
from tsai.all import *
from core import training, inference

# %%
df = pd.read_csv(Path(Path.cwd().parent.parent/'data/Trainingsdata/model input CSVs/input Forest Road.csv'), delimiter=';')
df = df.iloc[1650:6250]
df = training.dataframe.prepare(df)
training.dataframe.plot_all(df)

# %%
training.dataframe.plot_batches(df)
# Out:
# Too many batches. Display only the first and last 5.

# %%
training.dataframe.train(df)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.533941</td>
#       <td>0.356057</td>
#       <td>0.356057</td>
#       <td>0.214999</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.440143</td>
#       <td>0.337749</td>
#       <td>0.337749</td>
#       <td>0.197284</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.384400</td>
#       <td>0.321011</td>
#       <td>0.321011</td>
#       <td>0.186982</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.343296</td>
#       <td>0.308341</td>
#       <td>0.308341</td>
#       <td>0.183299</td>
#       <td>00:55</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.311213</td>
#       <td>0.299944</td>
#       <td>0.299944</td>
#       <td>0.183950</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.286568</td>
#       <td>0.302807</td>
#       <td>0.302807</td>
#       <td>0.195826</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.268322</td>
#       <td>0.299444</td>
#       <td>0.299444</td>
#       <td>0.201023</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.253824</td>
#       <td>0.300215</td>
#       <td>0.300215</td>
#       <td>0.207755</td>
#       <td>00:53</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.242593</td>
#       <td>0.312718</td>
#       <td>0.312718</td>
#       <td>0.231030</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.232630</td>
#       <td>0.322713</td>
#       <td>0.322713</td>
#       <td>0.247598</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.223500</td>
#       <td>0.330081</td>
#       <td>0.330081</td>
#       <td>0.263823</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.215245</td>
#       <td>0.341403</td>
#       <td>0.341403</td>
#       <td>0.284843</td>
#       <td>00:55</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.204877</td>
#       <td>0.327669</td>
#       <td>0.327669</td>
#       <td>0.264894</td>
#       <td>00:54</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.193461</td>
#       <td>0.337918</td>
#       <td>0.337918</td>
#       <td>0.282146</td>
#       <td>00:55</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.181731</td>
#       <td>0.352281</td>
#       <td>0.352281</td>
#       <td>0.304691</td>
#       <td>00:55</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.3560571074485779.
# Better model found at epoch 1 with valid_loss value: 0.33774861693382263.
# Better model found at epoch 2 with valid_loss value: 0.3210107982158661.
# Better model found at epoch 3 with valid_loss value: 0.308341383934021.
# Better model found at epoch 4 with valid_loss value: 0.2999438941478729.
# No improvement since epoch 4: early stopping

# %%
inference.dataframe.validate(df)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
