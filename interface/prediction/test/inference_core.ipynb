# %%
from tsai.all import *
from core import training, inferencing

# %%
edp = training.example_data_parameter(num_days=10, num_features=5)
df = edp.create_sample_dataframe()
training.dataframe.plot(df)
# Out:
# ['unique_id', 'var1', 'var2', 'var3', 'var4', 'var5', 'target']

# %%
inferencing.dataframe.validate(df)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
